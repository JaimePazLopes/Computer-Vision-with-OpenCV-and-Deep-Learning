# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
path = "gdrive/My Drive/Colab Notebooks/Computer Vision with OpenCV and Deep Learning/Image Processing/DATA/rainbow.jpg"
img = cv2.imread(path, 0)
plt.imshow(img, cmap="gray")

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY) #255/2
plt.imshow(thresh1, cmap="gray")

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC) #255/2
plt.imshow(thresh1, cmap="gray")

# %%
path = "gdrive/My Drive/Colab Notebooks/Computer Vision with OpenCV and Deep Learning/Image Processing/DATA/crossword.jpg"
img = cv2.imread(path, 0)
plt.imshow(img, cmap="gray")

# %%
def show_pic(img):
  fig = plt.figure(figsize=(15,15))
  ax = fig.add_subplot(111)
  ax.imshow(img, cmap="gray")

# %%
show_pic(img)

# %%
ret, th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
show_pic(th1)

# %%
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,
                            11,8)
show_pic(th2)

# %%
blended = cv2.addWeighted(th1, 0.6, th2, 0.4, 0)
show_pic(blended)
